# %% [markdown]
# #  Практические задания к уроку 6

# %% [markdown]
# ##  Тема “Элементы теории вероятностей

# %% [markdown]
# **1.Задание (теорема сложения).
# Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях которой имеются соответственно 1,2,3,4,5 и 6 очков.**

# %% [raw]
# Количество выпадений 2 очков = 1, 5 очков  = 1. Общее число вариантов = 6.
# Т.к. события выпадения 2 или 5 очков несовместны, то P(2,5) = P(2) + P(5).
# P(2) = 1 / 6
# P(5) = 1 / 6
# P(2,5) = P(2) + P(5) = 2/6 = 1/3

# %% [markdown]
# **2.Задание (теорема умножения).
# Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.**

# %% [raw]
# #P(AB) = P(A) * P(B/A)
# Вероятность выпадения в первой попытке числа 2, равна 1/6: P(2) = 1 / 6
# В второй попытке верятность выпадения числа 5, равна 1/6: P(5) = 1 /6
# Т.к. по условию, события зависимы, то выполнение условий задания, возможно с вероятностью P(2,5) = P(2) * P(5/2) = 1/6 * 1/6 = 1/36

# %% [markdown]
# **3.Задание. Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости.
# Обратите внимание на порядок выпадения костей!**

# %% [raw]
#     Вероятность выпадения в первой попытке числа 2, равна 1/6: P(2) = 1 / 6
# Во второй попытке вероятность выпадения числа 5, равна 1/6: P(5) = 1 /6
# По условию, события зависимы, следовательно выполнение условий задания, возможно с вероятностью
# P(2,5) = P(2) * P(5/2) = 1/6 * 1/6 = 1/36
#     Вероятность выпадения в первой попытке числа 5, равна 1/6: P(5) = 1 / 6
# Во второй попытке вероятность выпадения числа 2, равна 1/6: P(2) = 1 /6
# По условию, события зависимы, следовательно выполнение условий задания, возможно с вероятностью
# P(5,2) = P(5) * P(2/5) = 1/6 * 1/6 = 1/36
# Т.к. первый и второй варианты, события независимые, то общая вероятность заданного условием события:
# P = P((2,5),(5,2)) = P(2,5) + P(5,2) = 2/36 = 1/18

# %% [raw]
# Последовательность независимых событий

# %% [markdown]
# **4.Задание  (Геометрическая вероятность +интервалы)
# На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится на расстоянии не более 9 см от точки А и не более 15 см от точки В?**

# %% [raw]
# Согласно условиям задачи, точка должна лежать на отрезке, длина которого равна
# g = 9 + 15 - 20 = 4  - область благоприятная для события.
# Область событий (общая длина отрезка) равна 20, G = 20.
# Вероятность нахождения точки С в благоприятной области
# P = g / G = 0.2

# %% [markdown]
# **5.Задание. Телефонный номер состоит из 7 цифр. Какова вероятность,
# что это номер 8882227?**

# %% [raw]
# По условиям задачи, имеем 7 позиций, каждая из которых может иметь 10 вариантов
# Верятность, что номер будет иметь вид 8882227, впрочем, как и любой другой, состоящий из позиций, равна 1 / 10**7.

# %% [markdown]
# **7.Задание. Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, что эти цифры различны и среди них нет нуля, стал набирать их наудачу. Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? Какова вероятность того, что он угадает номер с первого раза?**

# %% [raw]
# Первая цифра имеет 9 возможных значений, вторая - 8 (одна цифра уже используется), поэтому возможно 9 * 8 = 72 вариантов, из которых правильный только один. Вероятность правильного выбора 1/72

# %% [markdown]
# **8.Задание (необязательное)
# Чёрный куб покрасили снаружи белой краской, затем разрезали на 27 одинаковых маленьких кубиков и как попало сложили из них большой куб. С какой вероятностью все грани этого куба будут белыми?**
